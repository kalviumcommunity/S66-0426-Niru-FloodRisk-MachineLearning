# %% [markdown]
# # Jupyter Notebook Setup & Configuration
#
# This notebook configures Jupyter for optimal development and data exploration.
#
# ## Overview
# - Install and import required packages
# - Configure display settings
# - Setup visualization tools
# - Enable magic commands
# - Verify configuration

# %% [markdown]
# ## 1. Install Required Packages

# %%
# Install Jupyter and useful extensions
import subprocess
    
,
,
,
jupyter",
    "jupyterlab",
    "ipywidgets",
    "numpy",
    "pandas",
    "matplotlib",
    "seaborn",
    "scikit-learn",
    "joblib"
]

print("Installing packages...")
for package in packages:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", package])
    print(f"✓ {package} installed")

print("\n✓ All packages installed successfully!")
markdown
## 2. Import Libraries & Configure Display
code

import warnings
import sys
import os
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML, Markdown

print("✓ Core libraries imported successfully")
markdown
## 3. Configure Pandas Display Options
code

# Configure pandas for better DataFrame display
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 20)
pd.set_option('display.width', 1000)
pd.set_option('display.precision', 4)
pd.set_option('display.float_format', '{:.4f}'.format)

print("✓ Pandas display options configured")
markdown
## 4. Configure Matplotlib & Seaborn
code

# %matplotlib inline

# Configure matplotlib
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['figure.dpi'] = 100
plt.rcParams['font.size'] = 10
plt.rcParams['axes.labelsize'] = 11
plt.rcParams['axes.titlesize'] = 13
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['legend.fontsize'] = 10

# Configure seaborn
sns.set_style('whitegrid')
sns.set_palette('husl')

print("✓ Matplotlib and Seaborn configured")
markdown
## 5. Configure NumPy & Warnings
code

# Configure NumPy
np.set_printoptions(precision=4, suppress=True)

# Suppress warnings
warnings.filterwarnings('ignore')

# Set random seed for reproducibility
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

print("✓ NumPy and warnings configured")
print(f"✓ Random state set to: {RANDOM_STATE}")
markdown
## 6. Setup Project Path
code

# Add project root to path
project_root = Path().resolve().parent
sys.path.insert(0, str(project_root))

print(f"✓ Project root: {project_root}")
print(f"✓ Python path configured")

# Verify key directories exist
data_dir = project_root / 'data'
src_dir = project_root / 'src'
models_dir = project_root / 'models'

print(f"\n✓ Data directory: {data_dir.exists()}")
print(f"✓ Source directory: {src_dir.exists()}")
print(f"✓ Models directory: {models_dir.exists()}")
markdown
## 7. Enable Auto-reload
code

# %load_ext autoreload
# %autoreload 2

print("✓ Auto-reload enabled (changes in modules automatically reloaded)")
markdown
## 8. Verify Configuration
code

# Display configuration summary
config_summary = f"""
## ✓ Jupyter Environment Configured Successfully!

### Library Versions:
- NumPy: {np.__version__}
- Pandas: {pd.__version__}
- Matplotlib: {plt.matplotlib.__version__}
- Seaborn: {sns.__version__}
- Scikit-learn: {__import__('sklearn').__version__}

### Configuration:
- Matplotlib backend: inline
- Random seed: {RANDOM_STATE}
- Pandas max rows: 100
- Pandas max columns: 20
- Warnings: suppressed
- Auto-reload: enabled

### Project Paths:
- Project root: {project_root}
- Data directory: {data_dir}
- Source directory: {src_dir}
"""

display(Markdown(config_summary))
markdown
## Ready to Go! 🚀

Your Jupyter environment is now fully configured and ready for data exploration and model development.

Next steps:
1. Open `01_quick_demo.ipynb` for a quick overview
2. Open `02_data_exploration.ipynb` to explore the data
3. Open `03_preprocessing_pipeline.ipynb` to learn about data preprocessing
