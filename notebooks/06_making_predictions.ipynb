# %% [markdown]
# # Making Predictions
#
# Use the trained model for predictions:
# 1. Load model and scaler
# 2. Single sample predictions
# 3. Batch predictions
# 4. Get probability scores
# 5. Export results

# %% [markdown]
# ## Setup

# %% [markdown]
# ## Step 1: Load Model and Scaler

# %% [markdown]
# ## Step 2: Create Sample Data

# %% [markdown]
# ## Step 3: Single Sample Prediction

# %% [markdown]
# ## Step 4: Batch Prediction from CSV

# %% [markdown]
# ## Step 5: Batch Predictions

# %% [markdown]
# ## Step 8: Export Results
